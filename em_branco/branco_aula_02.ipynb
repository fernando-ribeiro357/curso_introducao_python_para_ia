# %% [markdown]
# # Aula 2: Iterações repetidas - Loops e condicionais

# %%
print('Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)\n')
pergunta = input('Diga o seu nome e faça sua primeira pegunta: ')

while True:
  print(f'Bot: resposta do bot aqui')
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break

print(f'Muito obrigado por utilizar o AsimoBot')
# Out:
# Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)
#
# Diga o seu nome e faça sua primeira pegunta: Meu nome é Adriano quero saber quem sou eu?
# Bot: resposta do bot aqui
# Usuário: O que mais você pode me dizer?
# Bot: resposta do bot aqui
# Usuário: quantas perguntas eu quiser
# Bot: resposta do bot aqui
# Usuário: x
# Muito obrigado por utilizar o AsimoBot

# %% [markdown]
# ## Operadores de comparação
#
# Operadores de comparação são usados em programação para comparar dois valores e determinar a relação entre eles. O resultado da comparação é sempre um valor booleano, ou seja, True (verdadeiro) ou False (falso).

# %% [markdown]
# Aqui estão os principais operadores de comparação:
#
# - == (igual a): Verifica se dois valores são iguais.
# Exemplo: 5 == 5 resulta em True.
#
# - != (diferente de): Verifica se dois valores são diferentes.
# Exemplo: 5 != 3 resulta em True.
#
# - \> (maior que): Verifica se o valor à esquerda é maior que o valor à direita.
# Exemplo: 7 > 3 resulta em True.
#
# - < (menor que): Verifica se o valor à esquerda é menor que o valor à direita.
# Exemplo: 2 < 5 resulta em True.
#
# - \>= (maior ou igual a): Verifica se o valor à esquerda é maior ou igual ao valor à direita.
# Exemplo: 4 >= 4 resulta em True.
#
# - <= (menor ou igual a): Verifica se o valor à esquerda é menor ou igual ao valor à direita.
# Exemplo: 3 <= 5 resulta em True.
#
# Esses operadores são fundamentais para tomar decisões no código, como em condicionais (if) e loops, onde o programa precisa comparar valores para determinar qual ação executar a seguir.

# %%
pergunta = input('Digite \'sair\' para sair: ')
print(pergunta.lower() == 'sair')
# Out:
# Digite 'sair' para sair: exit
# True

# %% [markdown]
# ### Operadores lógicos
#
# Operadores lógicos são usados em programação para combinar condições ou inverter valores booleanos (True ou False). Eles ajudam a criar expressões lógicas mais complexas. Aqui estão os principais operadores lógicos:
#
# - and: Retorna True se todas as condições forem verdadeiras.
#
# > Exemplo: True and False resulta em False (porque nem todas as condições são verdadeiras).
#
# - or: Retorna True se pelo menos uma das condições for verdadeira.
#
# > Exemplo: True or False resulta em True (porque pelo menos uma condição é verdadeira).
#
# - not: Inverte o valor de uma condição, transformando True em False e vice-versa.
#
# > Exemplo: not True resulta em False.
#
# Esses operadores são usados para construir expressões lógicas que controlam o fluxo do programa, permitindo que ele tome decisões mais sofisticadas com base em múltiplas condições.

# %%
pergunta = input('Digite \'sair\' para sair: ')
print(pergunta.lower() == 'sair' or pergunta.lower() == 'bye' or pergunta.lower() == 'exit')
# Out:
# Digite 'sair' para sair: bye
# True

# %% [markdown]
# ## Estruturas condicionais if, elif e else
#
# Estruturas condicionais são usadas para tomar decisões no código com base em condições específicas. Elas permitem que o programa execute diferentes blocos de código dependendo se uma condição é verdadeira ou falsa.
#
# - if: Executa um bloco de código se a condição for verdadeira.
#
# - else: Executa um bloco de código se a condição do if não for verdadeira.
#
# - elif: Verifica múltiplas condições, se a condição do if não for verdadeira.

# %%
pergunta = input('Digite \'sair\' para sair: ')
if pergunta.lower() == 'sair' or pergunta.lower() == 'bye' or pergunta.lower() == 'exit':
  print('Saindo do programa...')
else:
  print('Continuar')
# Out:
# Digite 'sair' para sair: Exit
# Saindo do programa...

# %% [markdown]
# ## Estruturas de Repetição
#
# Estruturas de repetição, ou loops, são usadas para executar um bloco de código várias vezes de forma repetitiva. Elas são úteis quando você precisa realizar uma tarefa repetitiva sem escrever o mesmo código várias vezes.

# %% [markdown]
# ### Loop for
#
# O loop for itera sobre uma sequência de valores, como uma lista, range ou string, e executa o bloco de código para cada valor.

# %% [markdown]
# ### Loop while
#
# Continua executando o bloco de código enquanto uma condição for verdadeira.

# %%
print('''
   /)🎀(\\
  ( o __o)
  (  ( Y )
  (      )

Lulu >>> Olá. Eu sou a Lulu Lhama. Sou uma assistente feliz por poder ajudar.
 ''')
nome = input('Qual é o seu nome? ')
print(f'Olá {nome}, me diga qual é a sua dúvida: \n')
while True:
    pergunta = input(f'{nome} >>> ')

    if pergunta.lower() == 'sair' or pergunta.lower() == 'bye' or pergunta.lower() == 'exit' or pergunta.lower() == 'quit':
        print('\nSaindo do programa...\nObrigado por me consultar, estarei sempre aqui para te ajudar.\n')
        break

    resposta = 'Resposta do bot aqui'
    print(f'''
     /)🎀(\\
    ( o __o)
    (  ( Y )
    (      )

Lulu >>> {resposta}
''')
